# %% [markdown]
# # **Exploratory Data Analysis and Data Preprocessing**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import the dataset

data = pd.read_csv('AlzheimerData.csv')
data
# Out:
#             Country   Age  Gender  EducationLevel   BMI PhysicalActivityLevel  \
# 0             Spain  90.0    Male             1.0  33.0                   NaN
# 1         Argentina  72.0    Male             7.0  29.9                Medium
# 2      South Africa  86.0  Female            19.0  22.9                   NaN
# 3             China  53.0    Male            17.0  31.2                   Low
# 4            Sweden  58.0  Female             3.0  30.0                  High
# ...             ...   ...     ...             ...   ...                   ...
# 74278           NaN  60.0  Female             3.0  22.6                  High
# 74279            UK  58.0    Male            18.0  30.6                   Low
# 74280         Spain  57.0  Female            13.0  28.2                Medium
# 74281        Brazil  73.0  Female             7.0  29.0                   Low
# 74282        Norway  57.0  Female             1.0  31.7                   Low
#
#       SmokingStatus AlcoholConsumption Diabetes Hypertension  ...  \
# 0             Never       Occasionally      NaN           No  ...
# 1            Former              Never       No           No  ...
# 2           Current       Occasionally       No          Yes  ...
# 3             Never          Regularly      Yes           No  ...
# 4            Former              Never      Yes           No  ...
# ...             ...                ...      ...          ...  ...
# 74278        Former              Never       No           No  ...
# 74279         Never       Occasionally      Yes           No  ...
# 74280         Never          Regularly       No           No  ...
# 74281         Never          Regularly       No           No  ...
# 74282       Current          Regularly       No           No  ...
#
#       DietaryHabits AirPollutionExposure  EmploymentStatus MaritalStatus  \
# 0           Healthy                 High           Retired        Single
# 1           Healthy               Medium        Unemployed       Widowed
# 2           Average               Medium          Employed        Single
# 3           Healthy               Medium           Retired        Single
# 4         Unhealthy                 High          Employed       Married
# ...             ...                  ...               ...           ...
# 74278       Average                 High        Unemployed       Widowed
# 74279       Average               Medium        Unemployed        Single
# 74280       Healthy                  Low          Employed        Single
# 74281       Healthy                  Low          Employed       Widowed
# 74282       Average                  Low        Unemployed        Single
#
#       GeneticRisk SocialEngagementLevel IncomeLevel StressLevels UrbanRural  \
# 0              No                   Low      Medium         High      Urban
# 1              No                  High         Low         High      Urban
# 2              No                   Low      Medium         High      Rural
# 3              No                  High      Medium          Low      Rural
# 4              No                   Low      Medium         High      Rural
# ...           ...                   ...         ...          ...        ...
# 74278          No                Medium        High       Medium      Rural
# 74279          No                Medium        High         High      Rural
# 74280         Yes                  High         Low          Low      Rural
# 74281          No                   Low         Low         High      Rural
# 74282          No                   Low      Medium       Medium      Urban
#
#       AlzheimerDiagnosis
# 0                     No
# 1                     No
# 2                     No
# 3                     No
# 4                     No
# ...                  ...
# 74278                 No
# 74279                 No
# 74280                 No
# 74281                 No
# 74282                 No
#
# [74283 rows x 25 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74283 entries, 0 to 74282
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                72724 non-null  object
#  1   Age                    71298 non-null  float64
#  2   Gender                 70739 non-null  object
#  3   EducationLevel         73438 non-null  float64
#  4   BMI                    73851 non-null  float64
#  5   PhysicalActivityLevel  71557 non-null  object
#  6   SmokingStatus          72162 non-null  object
#  7   AlcoholConsumption     73466 non-null  object
#  8   Diabetes               72201 non-null  object
#  9   Hypertension           73326 non-null  object
#  10  CholesterolLevel       70777 non-null  object
#  11  AlzheimerInFamily      73655 non-null  object
#  12  CognitiveTestScore     70226 non-null  float64
#  13  DepressionLevel        73711 non-null  object
#  14  SleepQuality           71293 non-null  object
#  15  DietaryHabits          73079 non-null  object
#  16  AirPollutionExposure   71238 non-null  object
#  17  EmploymentStatus       72698 non-null  object
#  18  MaritalStatus          70498 non-null  object
#  19  GeneticRisk            72072 non-null  object
#  20  SocialEngagementLevel  73184 non-null  object
#  21  IncomeLevel            73321 non-null  object
#  22  StressLevels           73571 non-null  object
#  23  UrbanRural             70811 non-null  object
#  24  AlzheimerDiagnosis     74283 non-null  object
# dtypes: float64(4), object(21)
# memory usage: 14.2+ MB

# %%
# Data type correction

for col in data.columns:
    if data[col].dtype == 'object':
        data[col] = data[col].astype('category')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74283 entries, 0 to 74282
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                72724 non-null  category
#  1   Age                    71298 non-null  float64
#  2   Gender                 70739 non-null  category
#  3   EducationLevel         73438 non-null  float64
#  4   BMI                    73851 non-null  float64
#  5   PhysicalActivityLevel  71557 non-null  category
#  6   SmokingStatus          72162 non-null  category
#  7   AlcoholConsumption     73466 non-null  category
#  8   Diabetes               72201 non-null  category
#  9   Hypertension           73326 non-null  category
#  10  CholesterolLevel       70777 non-null  category
#  11  AlzheimerInFamily      73655 non-null  category
#  12  CognitiveTestScore     70226 non-null  float64
#  13  DepressionLevel        73711 non-null  category
#  14  SleepQuality           71293 non-null  category
#  15  DietaryHabits          73079 non-null  category
#  16  AirPollutionExposure   71238 non-null  category
#  17  EmploymentStatus       72698 non-null  category
#  18  MaritalStatus          70498 non-null  category
#  19  GeneticRisk            72072 non-null  category
#  20  SocialEngagementLevel  73184 non-null  category
#  21  IncomeLevel            73321 non-null  category
#  22  StressLevels           73571 non-null  category
#  23  UrbanRural             70811 non-null  category
#  24  AlzheimerDiagnosis     74283 non-null  category
# dtypes: category(21), float64(4)
# memory usage: 3.8 MB

# %%
data.describe()
# Out:
#                 Age  EducationLevel           BMI  CognitiveTestScore
# count  71298.000000    73438.000000  73851.000000        70226.000000
# mean      71.964571        9.488889     26.779651           64.660240
# std       12.984434        5.757648      4.764849           20.158604
# min       50.000000        0.000000     18.500000           30.000000
# 25%       61.000000        4.000000     22.700000           47.000000
# 50%       72.000000        9.000000     26.800000           65.000000
# 75%       83.000000       14.000000     30.900000           82.000000
# max       94.000000       19.000000     35.000000           99.000000

# %% [markdown]
# # Graphics

# %%
# Box plots for numerical variables

sns.boxplot(data = data)
# Out:
# <Axes: >

# %%
# For numerical variables

numerical_columns = data.select_dtypes(include = ['int64', 'float64']).columns

for c in numerical_columns:

    plt.figure(figsize = (8, 5))
    sns.histplot(data[c], kde = True)
    plt.title('Distribution of ' + c)
    plt.xlabel(c)
    plt.ylabel('Frequency')

    plt.show()

# %%
# For categorical variables

categorical_columns = data.select_dtypes(include = ['category']).columns

palette = sns.color_palette("dark", n_colors = len(categorical_columns))

sns.set(style = "whitegrid")

for i, col in enumerate(categorical_columns):

    plt.figure(figsize = (10, 6))
    sns.countplot(data = data, x = col, order = data[col].value_counts().index, color = palette[i % len(palette)])
    plt.xticks(rotation = 45)
    plt.title('Count of ' + col, fontsize = 12, fontweight = 'bold')
    plt.tight_layout()
    plt.xlabel(col)
    plt.ylabel('Count')

    plt.show()
